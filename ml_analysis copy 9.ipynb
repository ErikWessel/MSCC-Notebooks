# %%
import gc
import math
import os
from typing import List, Tuple

import matplotlib.pyplot as plt
import pandas as pd
import rasterio
import rasterio.plot
import seaborn as sns
import torch
import torch.backends.cudnn as cudnn
import torchvision.transforms as transforms
import yaml
from ml_commons import *
from torch import nn, optim
from torch.utils.data import DataLoader, WeightedRandomSampler
from torchvision.models import (EfficientNet_V2_S_Weights, Swin_V2_S_Weights,
                                efficientnet_v2_s, swin_v2_s)

cudnn.benchmark = True
sns.set_theme()

# %%
modify_model_config = False

# %%
config = yaml.safe_load(open('ml_config.yml'))

# %%
prefix_dir = config['paths']['prefix_dir']
dataset_dir = os.path.join(prefix_dir, config['paths']['dataset_dir'])
output_dir = os.path.join(config['paths']['machine_learning_dir'], 'output')
print(f'Using dataset: {dataset_dir}')
# Out:
# Using dataset: data\dataset_16km_300_ndsi

# %%
gc.collect()
with torch.no_grad():
    torch.cuda.empty_cache()

# %%
'ML/output/efficientnet_v2_s_preset_3_weighted_sampler_ord_regr.pt'
# Out:
# 'ML/output/efficientnet_v2_s_preset_3_weighted_sampler_ord_regr.pt'

# %%
state_filepath = os.path.join(config['paths']['machine_learning_dir'], 'output', 'efficientnet_v2_s_preset_3_16km_300_ndsi_weighted_sampler_ord_regr.pt')
state = load_state(state_filepath)
config = state.config

# %%
config
# Out:
# {'paths': {'prefix_dir': '/p/project/haf/users/wessel2/aimlsse',
#   'dataset_dir': 'dataset_16km_300_ndsi',
#   'machine_learning_dir': 'ML'},
#  'model': {'name': 'EfficientNet',
#   'freeze_parameters': False,
#   'use_transfer_learning': True},
#  'processing': {'batch_size': 48,
#   'batch_normalization': False,
#   'batch_accumulation': 1,
#   'num_epochs': 32,
#   'use_ordinal_regression': True,
#   'use_one_neuron_regression': False,
#   'ordinal_regression_loss': 'MSE',
#   'activation_function': 'Sigmoid',
#   'use_weighted_loss_function': False,
#   'use_weighted_sampler': True,
#   'use_manual_labels': False,
#   'optimizer': 'Adam',
#   'learning_rate_exp': 3,
#   'momentum': 0.9,
#   'use_dropout': False,
#   'dropout_p': 0.5,
#   'use_weight_decay': False,
#   'weight_decay_exp': 3},
#  'output': {'output_name': 'efficientnet_v2_s_preset_3_16km_300_ndsi_weighted_sampler_ord_regr.pt',
#   'show_samples': False,
#   'show_summary': False}}

# %%
def if_not_present_set(category:str, variable:str, value):
    if category not in config:
        print(f'Config - add category: {category}')
        config[category] = {}
    if variable not in config[category]:
        print(f'Config - add variable: {variable} with value {value}')
        config[category][variable] = value

# %%
if_not_present_set('processing', 'optimizer',           'Adam'  )
if_not_present_set('processing', 'learning_rate_exp',   3       )
if_not_present_set('processing', 'momentum',            0.9     )
if_not_present_set('processing', 'use_dropout',         True    )
if_not_present_set('processing', 'dropout_p',           0.2     )
if_not_present_set('processing', 'use_weight_decay',    False   )
if_not_present_set('processing', 'weight_decay_exp',    4       )
if_not_present_set('processing', 'batch_normalization', False   )
if_not_present_set('processing', 'use_manual_labels', False   )

# %%
if modify_model_config:
    state.config = config
    save_state(state_filepath, state)

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Using {device} for inference')
# Out:
# Using cuda for inference

# %%
def print_model(model:nn.Module, name:str):
    spacing = '  '
    model_str = spacing + f'\n{spacing}'.join(str(model).splitlines())
    print(f'--- {name} ---\n{model_str}\n{"-" * (8 + len(name))}')

# %%
print(f'Using model: ' + config['model']['name'])
model_name = str(config['model']['name']).lower()
if model_name == 'swintransformer':
    model = swin_v2_s(weights=Swin_V2_S_Weights.DEFAULT)
elif model_name == 'efficientnet':
    model = efficientnet_v2_s(weights=EfficientNet_V2_S_Weights.DEFAULT)
else:
    raise RuntimeError(f'Model "' + config['model']['name'] + '" is unknown')

if config['model']['freeze_parameters']:
    for param in model.parameters(): #freeze model
        param.requires_grad = False

print_model(get_model_head(model), 'Initial Model Head')
num_features = get_num_features(model)
print(f'Classification layer has {num_features} input features')
new_model_head = nn.Sequential()
# Before linear layer
if config['processing']['use_dropout']:
    new_model_head.append(nn.Dropout(p=config['processing']['dropout_p'], inplace=True))
# Linear layer
linear_layer = nn.Linear(num_features, 1 if config['processing']['use_one_neuron_regression'] else len(classes))
new_model_head.append(linear_layer)
# After linear layer
if (config['processing']['use_ordinal_regression'] or config['processing']['use_one_neuron_regression']) \
        and config['processing']['activation_function'] != False:
    activation_function = str(config['processing']['activation_function']).lower()
    if activation_function == 'sigmoid':
        activation_function = nn.Sigmoid()
    elif activation_function == 'relu':
        activation_function = nn.ReLU()
    elif activation_function == 'tanh':
        activation_function = nn.Tanh()
    else:
        raise RuntimeError(f'Unkown activation function: {activation_function}')
    new_model_head = new_model_head.append(activation_function)

set_model_head(model, new_model_head)
print_model(get_model_head(model), 'Modified Model Head')
# model = nn.DataParallel(model)
model = model.to(device)
# Out:
# Using model: EfficientNet
# --- Initial Model Head ---
#   Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# --------------------------
# Classification layer has 1280 input features
# --- Modified Model Head ---
#   Sequential(
#     (0): Linear(in_features=1280, out_features=5, bias=True)
#     (1): Sigmoid()
#   )
# ---------------------------

# %%
model_trained = model
model_trained.load_state_dict(state.model_state)
# Out:
# <All keys matched successfully>

# %%
def prediction_to_label_ordinal_regression(pred: torch.Tensor) -> torch.Tensor:
    return (pred > 0.5).cumprod(axis=1).sum(axis=1) - 1

# %%
def prediction_to_label_one_neuron_regression(pred: torch.Tensor) -> torch.Tensor:
    return ((pred * max(classes)).round()).int().flatten()

# %%
if config['processing']['use_ordinal_regression']:
    outputs_to_predictions = prediction_to_label_ordinal_regression
elif config['processing']['use_one_neuron_regression']:
    outputs_to_predictions = prediction_to_label_one_neuron_regression
else:
    outputs_to_predictions = lambda outputs: torch.max(outputs, 1)[1]

# %%
def mean_std(loader:DataLoader):
  sum, squared_sum, num_batches = 0,0,0
  for data, _, _ in loader:
    sum += torch.mean(data,dim=[0,1,2])
    squared_sum += torch.mean(data**2,dim=[0,1,2])
    num_batches += 1
  mean = sum/num_batches
  std = (squared_sum/num_batches - mean**2)**0.5
  return mean, std

# %%
def batch_normalization(dataset:AimlsseImageDataset, dataset_type:DatasetType, dataset_transforms):
    mean, std = mean_std(dataset)
    print(f'{dataset_type.name} - mean {mean:.3f}, std {std:.3f}')
    if dataset_transforms is None:
        dataset_transforms = []
    return AimlsseImageDataset(dataset_type, dataset_dir,
                               transfrom = transforms.Compose(dataset_transforms + [transforms.Normalize(mean, std)]))

# %%
visualization_dataset = AimlsseImageDataset(DatasetType.TEST, dataset_dir, transfrom=None,
    use_manual_labels = True)
if config['processing']['batch_normalization']:
    visualization_dataset = batch_normalization(visualization_dataset, DatasetType.TEST, None)
visualization_dataloader = DataLoader(visualization_dataset,  batch_size=2, shuffle=True)

# %%
from ptflops import get_model_complexity_info

get_model_complexity_info(model_trained, (3, 300, 300), as_strings=True, print_per_layer_stat=True, verbose=True)
# Out:
# Warning: module SiLU is treated as a zero-op.
# Warning: module Conv2dNormActivation is treated as a zero-op.
# Warning: module StochasticDepth is treated as a zero-op.
# Warning: module FusedMBConv is treated as a zero-op.
# Warning: module Sigmoid is treated as a zero-op.
# Warning: module SqueezeExcitation is treated as a zero-op.
# Warning: module MBConv is treated as a zero-op.
# Warning: module EfficientNet is treated as a zero-op.
# EfficientNet(
#   20.18 M, 100.000% Params, 5.36 GMac, 100.000% MACs,
#   (features): Sequential(
#     20.18 M, 99.968% Params, 5.36 GMac, 99.997% MACs,
#     (0): Conv2dNormActivation(
#       696, 0.003% Params, 15.66 MMac, 0.292% MACs,
#       (0): Conv2d(648, 0.003% Params, 14.58 MMac, 0.272% MACs, 3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(48, 0.000% Params, 1.08 MMac, 0.020% MACs, 24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#     )
#     (1): Sequential(
#       10.46 k, 0.052% Params, 235.44 MMac, 4.394% MACs,
#       (0): FusedMBConv(
#         5.23 k, 0.026% Params, 117.72 MMac, 2.197% MACs,
#         (block): Sequential(
#           5.23 k, 0.026% Params, 117.72 MMac, 2.197% MACs,
#           (0): Conv2dNormActivation(
#             5.23 k, 0.026% Params, 117.72 MMac, 2.197% MACs,
#             (0): Conv2d(5.18 k, 0.026% Params, 116.64 MMac, 2.177% MACs, 24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(48, 0.000% Params, 1.08 MMac, 0.020% MACs, 24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): FusedMBConv(
#         5.23 k, 0.026% Params, 117.72 MMac, 2.197% MACs,
#         (block): Sequential(
#           5.23 k, 0.026% Params, 117.72 MMac, 2.197% MACs,
#           (0): Conv2dNormActivation(
#             5.23 k, 0.026% Params, 117.72 MMac, 2.197% MACs,
#             (0): Conv2d(5.18 k, 0.026% Params, 116.64 MMac, 2.177% MACs, 24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(48, 0.000% Params, 1.08 MMac, 0.020% MACs, 24, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.005, mode=row)
#       )
#     )
#     (2): Sequential(
#       303.55 k, 1.504% Params, 1.71 GMac, 31.867% MACs,
#       (0): FusedMBConv(
#         25.63 k, 0.127% Params, 144.18 MMac, 2.691% MACs,
#         (block): Sequential(
#           25.63 k, 0.127% Params, 144.18 MMac, 2.691% MACs,
#           (0): Conv2dNormActivation(
#             20.93 k, 0.104% Params, 117.72 MMac, 2.197% MACs,
#             (0): Conv2d(20.74 k, 0.103% Params, 116.64 MMac, 2.177% MACs, 24, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(192, 0.001% Params, 1.08 MMac, 0.020% MACs, 96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             4.7 k, 0.023% Params, 26.46 MMac, 0.494% MACs,
#             (0): Conv2d(4.61 k, 0.023% Params, 25.92 MMac, 0.484% MACs, 96, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 540.0 KMac, 0.010% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.01, mode=row)
#       )
#       (1): FusedMBConv(
#         92.64 k, 0.459% Params, 521.1 MMac, 9.725% MACs,
#         (block): Sequential(
#           92.64 k, 0.459% Params, 521.1 MMac, 9.725% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.413% Params, 468.72 MMac, 8.748% MACs,
#             (0): Conv2d(82.94 k, 0.411% Params, 466.56 MMac, 8.707% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.002% Params, 2.16 MMac, 0.040% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             9.31 k, 0.046% Params, 52.38 MMac, 0.978% MACs,
#             (0): Conv2d(9.22 k, 0.046% Params, 51.84 MMac, 0.967% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 540.0 KMac, 0.010% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.015000000000000003, mode=row)
#       )
#       (2): FusedMBConv(
#         92.64 k, 0.459% Params, 521.1 MMac, 9.725% MACs,
#         (block): Sequential(
#           92.64 k, 0.459% Params, 521.1 MMac, 9.725% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.413% Params, 468.72 MMac, 8.748% MACs,
#             (0): Conv2d(82.94 k, 0.411% Params, 466.56 MMac, 8.707% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.002% Params, 2.16 MMac, 0.040% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             9.31 k, 0.046% Params, 52.38 MMac, 0.978% MACs,
#             (0): Conv2d(9.22 k, 0.046% Params, 51.84 MMac, 0.967% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 540.0 KMac, 0.010% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.02, mode=row)
#       )
#       (3): FusedMBConv(
#         92.64 k, 0.459% Params, 521.1 MMac, 9.725% MACs,
#         (block): Sequential(
#           92.64 k, 0.459% Params, 521.1 MMac, 9.725% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.413% Params, 468.72 MMac, 8.748% MACs,
#             (0): Conv2d(82.94 k, 0.411% Params, 466.56 MMac, 8.707% MACs, 48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.002% Params, 2.16 MMac, 0.040% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             9.31 k, 0.046% Params, 52.38 MMac, 0.978% MACs,
#             (0): Conv2d(9.22 k, 0.046% Params, 51.84 MMac, 0.967% MACs, 192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, 0.000% Params, 540.0 KMac, 0.010% MACs, 48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       589.18 k, 2.919% Params, 850.78 MMac, 15.878% MACs,
#       (0): FusedMBConv(
#         95.74 k, 0.474% Params, 138.25 MMac, 2.580% MACs,
#         (block): Sequential(
#           95.74 k, 0.474% Params, 138.25 MMac, 2.580% MACs,
#           (0): Conv2dNormActivation(
#             83.33 k, 0.413% Params, 120.33 MMac, 2.246% MACs,
#             (0): Conv2d(82.94 k, 0.411% Params, 119.77 MMac, 2.235% MACs, 48, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(384, 0.002% Params, 554.5 KMac, 0.010% MACs, 192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             12.42 k, 0.062% Params, 17.93 MMac, 0.335% MACs,
#             (0): Conv2d(12.29 k, 0.061% Params, 17.74 MMac, 0.331% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, 0.001% Params, 184.83 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.030000000000000006, mode=row)
#       )
#       (1): FusedMBConv(
#         164.48 k, 0.815% Params, 237.51 MMac, 4.433% MACs,
#         (block): Sequential(
#           164.48 k, 0.815% Params, 237.51 MMac, 4.433% MACs,
#           (0): Conv2dNormActivation(
#             147.97 k, 0.733% Params, 213.67 MMac, 3.988% MACs,
#             (0): Conv2d(147.46 k, 0.731% Params, 212.93 MMac, 3.974% MACs, 64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 739.33 KMac, 0.014% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.51 k, 0.082% Params, 23.84 MMac, 0.445% MACs,
#             (0): Conv2d(16.38 k, 0.081% Params, 23.66 MMac, 0.442% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, 0.001% Params, 184.83 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.035, mode=row)
#       )
#       (2): FusedMBConv(
#         164.48 k, 0.815% Params, 237.51 MMac, 4.433% MACs,
#         (block): Sequential(
#           164.48 k, 0.815% Params, 237.51 MMac, 4.433% MACs,
#           (0): Conv2dNormActivation(
#             147.97 k, 0.733% Params, 213.67 MMac, 3.988% MACs,
#             (0): Conv2d(147.46 k, 0.731% Params, 212.93 MMac, 3.974% MACs, 64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 739.33 KMac, 0.014% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.51 k, 0.082% Params, 23.84 MMac, 0.445% MACs,
#             (0): Conv2d(16.38 k, 0.081% Params, 23.66 MMac, 0.442% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, 0.001% Params, 184.83 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#       )
#       (3): FusedMBConv(
#         164.48 k, 0.815% Params, 237.51 MMac, 4.433% MACs,
#         (block): Sequential(
#           164.48 k, 0.815% Params, 237.51 MMac, 4.433% MACs,
#           (0): Conv2dNormActivation(
#             147.97 k, 0.733% Params, 213.67 MMac, 3.988% MACs,
#             (0): Conv2d(147.46 k, 0.731% Params, 212.93 MMac, 3.974% MACs, 64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 739.33 KMac, 0.014% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.51 k, 0.082% Params, 23.84 MMac, 0.445% MACs,
#             (0): Conv2d(16.38 k, 0.081% Params, 23.66 MMac, 0.442% MACs, 256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(128, 0.001% Params, 184.83 KMac, 0.003% MACs, 64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.045, mode=row)
#       )
#     )
#     (4): Sequential(
#       917.68 k, 4.547% Params, 287.59 MMac, 5.367% MACs,
#       (0): MBConv(
#         61.2 k, 0.303% Params, 37.44 MMac, 0.699% MACs,
#         (block): Sequential(
#           61.2 k, 0.303% Params, 37.44 MMac, 0.699% MACs,
#           (0): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 24.4 MMac, 0.455% MACs,
#             (0): Conv2d(16.38 k, 0.081% Params, 23.66 MMac, 0.442% MACs, 64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 739.33 KMac, 0.014% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             2.82 k, 0.014% Params, 1.02 MMac, 0.019% MACs,
#             (0): Conv2d(2.3 k, 0.011% Params, 831.74 KMac, 0.016% MACs, 256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=256, bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 184.83 KMac, 0.003% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             8.46 k, 0.042% Params, 100.88 KMac, 0.002% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 92.42 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(4.11 k, 0.020% Params, 4.11 KMac, 0.000% MACs, 256, 16, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4.35 k, 0.022% Params, 4.35 KMac, 0.000% MACs, 16, 256, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             33.02 k, 0.164% Params, 11.92 MMac, 0.222% MACs,
#             (0): Conv2d(32.77 k, 0.162% Params, 11.83 MMac, 0.221% MACs, 256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, 0.001% Params, 92.42 KMac, 0.002% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#       (1): MBConv(
#         171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#         (block): Sequential(
#           171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#           (0): Conv2dNormActivation(
#             66.56 k, 0.330% Params, 24.03 MMac, 0.448% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             5.63 k, 0.028% Params, 2.03 MMac, 0.038% MACs,
#             (0): Conv2d(4.61 k, 0.023% Params, 1.66 MMac, 0.031% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             33.31 k, 0.165% Params, 218.14 KMac, 0.004% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 184.83 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(16.42 k, 0.081% Params, 16.42 KMac, 0.000% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16.9 k, 0.084% Params, 16.9 KMac, 0.000% MACs, 32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             65.79 k, 0.326% Params, 23.75 MMac, 0.443% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, 0.001% Params, 92.42 KMac, 0.002% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05500000000000001, mode=row)
#       )
#       (2): MBConv(
#         171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#         (block): Sequential(
#           171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#           (0): Conv2dNormActivation(
#             66.56 k, 0.330% Params, 24.03 MMac, 0.448% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             5.63 k, 0.028% Params, 2.03 MMac, 0.038% MACs,
#             (0): Conv2d(4.61 k, 0.023% Params, 1.66 MMac, 0.031% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             33.31 k, 0.165% Params, 218.14 KMac, 0.004% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 184.83 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(16.42 k, 0.081% Params, 16.42 KMac, 0.000% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16.9 k, 0.084% Params, 16.9 KMac, 0.000% MACs, 32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             65.79 k, 0.326% Params, 23.75 MMac, 0.443% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, 0.001% Params, 92.42 KMac, 0.002% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06000000000000001, mode=row)
#       )
#       (3): MBConv(
#         171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#         (block): Sequential(
#           171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#           (0): Conv2dNormActivation(
#             66.56 k, 0.330% Params, 24.03 MMac, 0.448% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             5.63 k, 0.028% Params, 2.03 MMac, 0.038% MACs,
#             (0): Conv2d(4.61 k, 0.023% Params, 1.66 MMac, 0.031% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             33.31 k, 0.165% Params, 218.14 KMac, 0.004% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 184.83 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(16.42 k, 0.081% Params, 16.42 KMac, 0.000% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16.9 k, 0.084% Params, 16.9 KMac, 0.000% MACs, 32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             65.79 k, 0.326% Params, 23.75 MMac, 0.443% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, 0.001% Params, 92.42 KMac, 0.002% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.065, mode=row)
#       )
#       (4): MBConv(
#         171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#         (block): Sequential(
#           171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#           (0): Conv2dNormActivation(
#             66.56 k, 0.330% Params, 24.03 MMac, 0.448% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             5.63 k, 0.028% Params, 2.03 MMac, 0.038% MACs,
#             (0): Conv2d(4.61 k, 0.023% Params, 1.66 MMac, 0.031% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             33.31 k, 0.165% Params, 218.14 KMac, 0.004% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 184.83 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(16.42 k, 0.081% Params, 16.42 KMac, 0.000% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16.9 k, 0.084% Params, 16.9 KMac, 0.000% MACs, 32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             65.79 k, 0.326% Params, 23.75 MMac, 0.443% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, 0.001% Params, 92.42 KMac, 0.002% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07, mode=row)
#       )
#       (5): MBConv(
#         171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#         (block): Sequential(
#           171.3 k, 0.849% Params, 50.03 MMac, 0.934% MACs,
#           (0): Conv2dNormActivation(
#             66.56 k, 0.330% Params, 24.03 MMac, 0.448% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             5.63 k, 0.028% Params, 2.03 MMac, 0.038% MACs,
#             (0): Conv2d(4.61 k, 0.023% Params, 1.66 MMac, 0.031% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#             (1): BatchNorm2d(1.02 k, 0.005% Params, 369.66 KMac, 0.007% MACs, 512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             33.31 k, 0.165% Params, 218.14 KMac, 0.004% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 184.83 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(16.42 k, 0.081% Params, 16.42 KMac, 0.000% MACs, 512, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(16.9 k, 0.084% Params, 16.9 KMac, 0.000% MACs, 32, 512, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             65.79 k, 0.326% Params, 23.75 MMac, 0.443% MACs,
#             (0): Conv2d(65.54 k, 0.325% Params, 23.66 MMac, 0.442% MACs, 512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, 0.001% Params, 92.42 KMac, 0.002% MACs, 128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.075, mode=row)
#       )
#     )
#     (5): Sequential(
#       3.46 M, 17.161% Params, 1.01 GMac, 18.877% MACs,
#       (0): MBConv(
#         281.44 k, 1.394% Params, 83.89 MMac, 1.566% MACs,
#         (block): Sequential(
#           281.44 k, 1.394% Params, 83.89 MMac, 1.566% MACs,
#           (0): Conv2dNormActivation(
#             99.84 k, 0.495% Params, 36.04 MMac, 0.673% MACs,
#             (0): Conv2d(98.3 k, 0.487% Params, 35.49 MMac, 0.662% MACs, 128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.54 k, 0.008% Params, 554.5 KMac, 0.010% MACs, 768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             8.45 k, 0.042% Params, 3.05 MMac, 0.057% MACs,
#             (0): Conv2d(6.91 k, 0.034% Params, 2.5 MMac, 0.047% MACs, 768, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=768, bias=False)
#             (1): BatchNorm2d(1.54 k, 0.008% Params, 554.5 KMac, 0.010% MACs, 768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             49.95 k, 0.247% Params, 327.2 KMac, 0.006% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 277.25 KMac, 0.005% MACs, output_size=1)
#             (fc1): Conv2d(24.61 k, 0.122% Params, 24.61 KMac, 0.000% MACs, 768, 32, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(25.34 k, 0.126% Params, 25.34 KMac, 0.000% MACs, 32, 768, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             123.2 k, 0.610% Params, 44.48 MMac, 0.830% MACs,
#             (0): Conv2d(122.88 k, 0.609% Params, 44.36 MMac, 0.828% MACs, 768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#       )
#       (1): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.085, mode=row)
#       )
#       (2): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09, mode=row)
#       )
#       (3): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.095, mode=row)
#       )
#       (4): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (5): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10500000000000001, mode=row)
#       )
#       (6): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11000000000000001, mode=row)
#       )
#       (7): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11500000000000002, mode=row)
#       )
#       (8): MBConv(
#         397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#         (block): Sequential(
#           397.8 k, 1.971% Params, 115.94 MMac, 2.164% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 3.81 MMac, 0.071% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 3.12 MMac, 0.058% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 424.36 KMac, 0.008% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 346.56 KMac, 0.006% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             153.92 k, 0.763% Params, 55.57 MMac, 1.037% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, 0.002% Params, 115.52 KMac, 0.002% MACs, 160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12000000000000002, mode=row)
#       )
#     )
#     (6): Sequential(
#       14.56 M, 72.146% Params, 1.22 GMac, 22.706% MACs,
#       (0): MBConv(
#         490.15 k, 2.428% Params, 82.0 MMac, 1.530% MACs,
#         (block): Sequential(
#           490.15 k, 2.428% Params, 82.0 MMac, 1.530% MACs,
#           (0): Conv2dNormActivation(
#             155.52 k, 0.771% Params, 56.14 MMac, 1.048% MACs,
#             (0): Conv2d(153.6 k, 0.761% Params, 55.45 MMac, 1.035% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 693.12 KMac, 0.013% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             10.56 k, 0.052% Params, 1.06 MMac, 0.020% MACs,
#             (0): Conv2d(8.64 k, 0.043% Params, 864.0 KMac, 0.016% MACs, 960, 960, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=960, bias=False)
#             (1): BatchNorm2d(1.92 k, 0.010% Params, 192.0 KMac, 0.004% MACs, 960, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             77.8 k, 0.385% Params, 173.8 KMac, 0.003% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 96.0 KMac, 0.002% MACs, output_size=1)
#             (fc1): Conv2d(38.44 k, 0.190% Params, 38.44 KMac, 0.001% MACs, 960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(39.36 k, 0.195% Params, 39.36 KMac, 0.001% MACs, 40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             246.27 k, 1.220% Params, 24.63 MMac, 0.460% MACs,
#             (0): Conv2d(245.76 k, 1.218% Params, 24.58 MMac, 0.459% MACs, 960, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#       (1): MBConv(
#         1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#         (block): Sequential(
#           1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#           (0): Conv2dNormActivation(
#             396.29 k, 1.963% Params, 39.63 MMac, 0.740% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
# ...
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
#             (0): Conv2d(13.82 k, 0.068% Params, 1.38 MMac, 0.026% MACs, 1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             198.21 k, 0.982% Params, 351.81 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 153.6 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(98.37 k, 0.487% Params, 98.37 KMac, 0.002% MACs, 1536, 64, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(99.84 k, 0.495% Params, 99.84 KMac, 0.002% MACs, 64, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             393.73 k, 1.951% Params, 39.37 MMac, 0.735% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.165, mode=row)
#       )
#       (9): MBConv(
#         1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#         (block): Sequential(
#           1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#           (0): Conv2dNormActivation(
#             396.29 k, 1.963% Params, 39.63 MMac, 0.740% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
#             (0): Conv2d(13.82 k, 0.068% Params, 1.38 MMac, 0.026% MACs, 1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             198.21 k, 0.982% Params, 351.81 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 153.6 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(98.37 k, 0.487% Params, 98.37 KMac, 0.002% MACs, 1536, 64, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(99.84 k, 0.495% Params, 99.84 KMac, 0.002% MACs, 64, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             393.73 k, 1.951% Params, 39.37 MMac, 0.735% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17, mode=row)
#       )
#       (10): MBConv(
#         1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#         (block): Sequential(
#           1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#           (0): Conv2dNormActivation(
#             396.29 k, 1.963% Params, 39.63 MMac, 0.740% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
#             (0): Conv2d(13.82 k, 0.068% Params, 1.38 MMac, 0.026% MACs, 1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             198.21 k, 0.982% Params, 351.81 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 153.6 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(98.37 k, 0.487% Params, 98.37 KMac, 0.002% MACs, 1536, 64, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(99.84 k, 0.495% Params, 99.84 KMac, 0.002% MACs, 64, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             393.73 k, 1.951% Params, 39.37 MMac, 0.735% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.175, mode=row)
#       )
#       (11): MBConv(
#         1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#         (block): Sequential(
#           1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#           (0): Conv2dNormActivation(
#             396.29 k, 1.963% Params, 39.63 MMac, 0.740% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
#             (0): Conv2d(13.82 k, 0.068% Params, 1.38 MMac, 0.026% MACs, 1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             198.21 k, 0.982% Params, 351.81 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 153.6 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(98.37 k, 0.487% Params, 98.37 KMac, 0.002% MACs, 1536, 64, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(99.84 k, 0.495% Params, 99.84 KMac, 0.002% MACs, 64, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             393.73 k, 1.951% Params, 39.37 MMac, 0.735% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18, mode=row)
#       )
#       (12): MBConv(
#         1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#         (block): Sequential(
#           1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#           (0): Conv2dNormActivation(
#             396.29 k, 1.963% Params, 39.63 MMac, 0.740% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
#             (0): Conv2d(13.82 k, 0.068% Params, 1.38 MMac, 0.026% MACs, 1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             198.21 k, 0.982% Params, 351.81 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 153.6 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(98.37 k, 0.487% Params, 98.37 KMac, 0.002% MACs, 1536, 64, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(99.84 k, 0.495% Params, 99.84 KMac, 0.002% MACs, 64, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             393.73 k, 1.951% Params, 39.37 MMac, 0.735% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.185, mode=row)
#       )
#       (13): MBConv(
#         1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#         (block): Sequential(
#           1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#           (0): Conv2dNormActivation(
#             396.29 k, 1.963% Params, 39.63 MMac, 0.740% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
#             (0): Conv2d(13.82 k, 0.068% Params, 1.38 MMac, 0.026% MACs, 1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             198.21 k, 0.982% Params, 351.81 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 153.6 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(98.37 k, 0.487% Params, 98.37 KMac, 0.002% MACs, 1536, 64, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(99.84 k, 0.495% Params, 99.84 KMac, 0.002% MACs, 64, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             393.73 k, 1.951% Params, 39.37 MMac, 0.735% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19, mode=row)
#       )
#       (14): MBConv(
#         1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#         (block): Sequential(
#           1.01 M, 4.980% Params, 81.04 MMac, 1.513% MACs,
#           (0): Conv2dNormActivation(
#             396.29 k, 1.963% Params, 39.63 MMac, 0.740% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             16.9 k, 0.084% Params, 1.69 MMac, 0.032% MACs,
#             (0): Conv2d(13.82 k, 0.068% Params, 1.38 MMac, 0.026% MACs, 1536, 1536, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1536, bias=False)
#             (1): BatchNorm2d(3.07 k, 0.015% Params, 307.2 KMac, 0.006% MACs, 1536, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#           )
#           (2): SqueezeExcitation(
#             198.21 k, 0.982% Params, 351.81 KMac, 0.007% MACs,
#             (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 153.6 KMac, 0.003% MACs, output_size=1)
#             (fc1): Conv2d(98.37 k, 0.487% Params, 98.37 KMac, 0.002% MACs, 1536, 64, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(99.84 k, 0.495% Params, 99.84 KMac, 0.002% MACs, 64, 1536, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#             (scale_activation): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#           )
#           (3): Conv2dNormActivation(
#             393.73 k, 1.951% Params, 39.37 MMac, 0.735% MACs,
#             (0): Conv2d(393.22 k, 1.948% Params, 39.32 MMac, 0.734% MACs, 1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(512, 0.003% Params, 51.2 KMac, 0.001% MACs, 256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.195, mode=row)
#       )
#     )
#     (7): Conv2dNormActivation(
#       330.24 k, 1.636% Params, 33.02 MMac, 0.616% MACs,
#       (0): Conv2d(327.68 k, 1.623% Params, 32.77 MMac, 0.612% MACs, 256, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2.56 k, 0.013% Params, 256.0 KMac, 0.005% MACs, 1280, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(0, 0.000% Params, 0.0 Mac, 0.000% MACs, inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 128.0 KMac, 0.002% MACs, output_size=1)
#   (classifier): Sequential(
#     6.41 k, 0.032% Params, 6.41 KMac, 0.000% MACs,
#     (0): Linear(6.41 k, 0.032% Params, 6.41 KMac, 0.000% MACs, in_features=1280, out_features=5, bias=True)
#     (1): Sigmoid(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#   )
# )
# ('5.36 GMac', '20.18 M')

# %%
cm_data = display_confusion_matrix(model_trained, device, visualization_dataloader, outputs_to_predictions,
                                   ConfusionMatrixNormalization.TRUE_LABELS)
# Out:
# 1286 predictions in 16.25 seconds
#       true label  predicted label  index
# 0              0                2     48
# 1              0                0    224
# 2              0                0    522
# 3              3                3    263
# 4              3                3    472
# ...          ...              ...    ...
# 1281           4                4    918
# 1282           0                0     43
# 1283           3                4     76
# 1284           4                4   1208
# 1285           3                4    894
#
# [1286 rows x 3 columns]

# %%
cm_data
# Out:
#      true label predicted label  index
# 0           OVC             BKN    186
# 1           OVC             OVC    144
# 2           OVC             OVC    977
# 3           CLR             CLR     71
# 4           CLR             CLR    895
# ...         ...             ...    ...
# 1281        BKN             BKN    510
# 1282        OVC             BKN   1247
# 1283        BKN             BKN    694
# 1284        BKN             BKN    113
# 1285        FEW             CLR   1074
#
# [1286 rows x 3 columns]

# %%
from collections import Counter

cc_counts = {}
fig, axs = plt.subplots(figsize=(4 * len(class_names), 5), ncols=len(class_names))
fig.suptitle('Predicted label classification for each cloud coverage derived from METARs')
for i, cc in enumerate(class_names):
    ax: plt.Axes = axs[i]
    counted_labels = pd.Series(Counter(cm_data[cm_data['true label'] == cc]['predicted label']))
    for cc_ in class_names:
        if cc_ not in counted_labels:
            counted_labels[cc_] = 0
    counted_labels = counted_labels.loc[class_names]
    counted_labels.plot.bar(ax=ax, title=cc)
    cc_counts[cc] = counted_labels

# %%
# rows   = label given by METAR
# colums = predicted label
cc_dist = pd.DataFrame(cc_counts).T
cc_dist
# Out:
#      CLR  FEW  SCT  BKN  OVC
# CLR  195   80    2    1    1
# FEW   65  105   40    2    0
# SCT   10   38  134   11    2
# BKN    2   22   62  152  134
# OVC    2    1    8   30  187

# %%
cc_dist_rel = (cc_dist.T / cc_dist.sum(axis=1)).T
assert(all([math.isclose(x, 1.0) for x in cc_dist_rel.sum(axis=1)]))
cc_dist_rel
# Out:
#           CLR       FEW       SCT       BKN       OVC
# CLR  0.698925  0.286738  0.007168  0.003584  0.003584
# FEW  0.306604  0.495283  0.188679  0.009434  0.000000
# SCT  0.051282  0.194872  0.687179  0.056410  0.010256
# BKN  0.005376  0.059140  0.166667  0.408602  0.360215
# OVC  0.008772  0.004386  0.035088  0.131579  0.820175

# %%
def direct_neighbor_accumulation(data_collection:List[pd.DataFrame], labels:List[str]) -> pd.DataFrame:
    result = []
    for i, cc in enumerate(class_names):
        local_result = {'cloud cover': cc}
        for k, data in enumerate(data_collection):
            cc_sum = data.loc[cc, cc]
            if i > 0:
                cc_sum += data.loc[cc, class_names[i - 1]]
            if i < len(class_names) - 1:
                cc_sum += data.loc[cc, class_names[i + 1]]
            local_result[labels[k]] = cc_sum
        result += [local_result]
    result = pd.DataFrame(result)
    result.set_index('cloud cover', inplace=True)
    return result

cc_neighbor_acc = direct_neighbor_accumulation([cc_dist_rel], ['f1_score'])
cc_neighbor_acc
# Out:
#              f1_score
# cloud cover
# CLR          0.985663
# FEW          0.990566
# SCT          0.938462
# BKN          0.935484
# OVC          0.951754

# %%
ax = cc_neighbor_acc.plot.bar(legend=False, rot=0)
ax.set_ylim(0, 1)
ax.set_xlabel(None)
ax.set_title('F1-Score (Direct Neighbor Accumulation)', pad=20)
ax.bar_label(ax.containers[0], fmt='%.3f')
# Out:
# [Text(0, 0, '0.986'),
#  Text(0, 0, '0.991'),
#  Text(0, 0, '0.938'),
#  Text(0, 0, '0.935'),
#  Text(0, 0, '0.952')]

# %%
false_predictions = cm_data[cm_data['true label'] != cm_data['predicted label']].copy()
print(f'{false_predictions.shape[0]} of {cm_data.shape[0]} images were not identified correctly'
      f' [{false_predictions.shape[0] / cm_data.shape[0] * 100.0:.2f} %]')
# Out:
# 513 of 1286 images were not identified correctly [39.89 %]

# %%
false_predictions_grouped = [false_predictions[false_predictions['true label'] == cc] for cc in class_names]
all_predictions_grouped = [cm_data[cm_data['true label'] == cc] for cc in class_names]
for i, cc in enumerate(class_names):
    print(f'{false_predictions_grouped[i].shape[0]} of {all_predictions_grouped[i].shape[0]} {cc} images were not identified correctly'
        f' [{false_predictions_grouped[i].shape[0] / all_predictions_grouped[i].shape[0] * 100.0:.2f} %]')
# Out:
# 84 of 279 CLR images were not identified correctly [30.11 %]
# 107 of 212 FEW images were not identified correctly [50.47 %]
# 61 of 195 SCT images were not identified correctly [31.28 %]
# 220 of 372 BKN images were not identified correctly [59.14 %]
# 41 of 228 OVC images were not identified correctly [17.98 %]

# %%
false_predictions['image path'] = false_predictions['index'].apply(lambda x: visualization_dataset.get_image_path(x))
false_predictions['timedelta [minutes]'] = false_predictions['index'].apply(lambda x: visualization_dataset.get_timedelta_minutes(x))
false_predictions
# Out:
#      true label predicted label  index  \
# 0           OVC             BKN    186
# 7           BKN             OVC    281
# 8           BKN             OVC   1251
# 9           BKN             SCT    967
# 10          CLR             FEW   1256
# ...         ...             ...    ...
# 1264        FEW             SCT    772
# 1267        BKN             OVC    894
# 1269        CLR             FEW    658
# 1282        OVC             BKN   1247
# 1285        FEW             CLR   1074
#
#                                              image path  timedelta [minutes]
# 0     data\dataset_16km_300_ndsi\test\NSI\8dceaca0-7...            13.649600
# 7     data\dataset_16km_300_ndsi\test\NSI\d9bcb400-1...            13.682933
# 8     data\dataset_16km_300_ndsi\test\DKR\e87d8943-7...            -3.850400
# 9     data\dataset_16km_300_ndsi\test\COM\548bd421-d...             1.149600
# 10    data\dataset_16km_300_ndsi\test\PRX\eaaef9cf-6...           -10.017067
# ...                                                 ...                  ...
# 1264  data\dataset_16km_300_ndsi\test\MKY\d6ffab34-d...           -11.017067
# 1267  data\dataset_16km_300_ndsi\test\4F2\33bb45c8-f...             6.316267
# 1269  data\dataset_16km_300_ndsi\test\SGJ\39c9f9d6-d...            -3.017067
# 1282  data\dataset_16km_300_ndsi\test\PRX\e5c5560c-9...            -6.317083
# 1285  data\dataset_16km_300_ndsi\test\EBG\8ee41fc9-f...            -9.650400
#
# [513 rows x 5 columns]

# %%
false_predictions_idx = 0

# %%
if false_predictions_idx < len(visualization_dataset):
    row = false_predictions.iloc[false_predictions_idx]
    image = rasterio.open(row['image path'])
    image_tensor = torch.from_numpy(image.read())
    image.close()

    plt.title(row[['true label', 'predicted label', 'timedelta [minutes]']].to_string(float_format=(lambda x: f'{x:.1f}')))
    plt.axis('off')
    plt.imshow(image_tensor.permute(1, 2, 0))
    false_predictions_idx += 1

# %%
pd.set_option('display.max_colwidth', None)

# %%
scoreboard = pd.DataFrame(state.scoreboard)
scoreboard['accuracy'] = scoreboard['accuracy'].apply(lambda t: t.item())
scoreboard.head()
# Out:
#    epoch       phase      loss  accuracy  precision    recall  f1_score  \
# 0      0    Training  0.644762  0.379537   0.435242  0.379537  0.393589
# 1      0  Validation  0.516863  0.572104   0.722989  0.572104  0.623139
# 2      1    Training  0.543011  0.450265   0.479532  0.450265  0.459883
# 3      1  Validation  0.496211  0.557132   0.742668  0.557132  0.616708
# 4      2    Training  0.519996  0.466843   0.492471  0.466843  0.474879
#
#          time  precision CLR  recall CLR  ...  f1_score FEW  precision SCT  \
# 0  261.575682       0.560229    0.290675  ...      0.357656       0.326142
# 1   37.934139       0.945824    0.618907  ...      0.138211       0.180851
# 2  156.619114       0.629352    0.447790  ...      0.379615       0.349581
# 3    6.703005       0.960199    0.570162  ...      0.116364       0.196809
# 4  140.363480       0.652589    0.471921  ...      0.402179       0.362715
#
#    recall SCT  f1_score SCT  precision BKN  recall BKN  f1_score BKN  \
# 0    0.432729      0.371950       0.325516    0.284252      0.303488
# 1    0.419753      0.252788       0.314607    0.207407      0.250000
# 2    0.436627      0.388285       0.378721    0.328551      0.351857
# 3    0.456790      0.275093       0.280423    0.392593      0.327160
# 4    0.449275      0.401381       0.372881    0.329013      0.349576
#
#    precision OVC  recall OVC  f1_score OVC
# 0       0.651911    0.482861      0.554795
# 1       0.695122    0.742671      0.718110
# 2       0.690256    0.636546      0.662314
# 3       0.759717    0.700326      0.728814
# 4       0.699578    0.645712      0.671566
#
# [5 rows x 23 columns]

# %%
print(f'Total time: {scoreboard.time.sum() / 60:.1f} [minutes]')
# Out:
# Total time: 71.1 [minutes]

# %%
scoreboard_training = scoreboard[scoreboard['phase'] == 'Training']
scoreboard_validation = scoreboard[scoreboard['phase'] == 'Validation']

# %%
def plot_scoreboard(x_label:str, y_labels:List[str], figsize:Tuple[float, float]):
    def plot_single(ax:plt.Axes, data:pd.DataFrame, y_label:str, phase:str, colors):
        ax.plot(x_label, y_label, data=data, label=phase, color=colors[phase])
        ax.legend(loc='best')
        ax.set_xlabel(x_label)
        ax.set_ylabel(y_label)
        ax.set_title(y_label)
        if y_label.startswith('f1_score') or y_label.startswith('precision') or y_label.startswith('recall') or y_label.startswith('accuracy'):
            ax.set_ylim(0, 1)

    assert x_label in scoreboard, f'Label {x_label} is not in scoreboard'
    for y_label in y_labels:
        assert y_label in scoreboard, f'Label {y_label} is not in scoreboard'
    colors = {
        'Training': 'lightseagreen',
        'Validation': 'mediumvioletred'
    }
    fig, axs = plt.subplots(figsize=(figsize[0] * len(y_labels), figsize[1]), ncols=len(y_labels))
    for phase in ['Training', 'Validation']:
        data = scoreboard[scoreboard['phase'] == phase]
        if isinstance(axs, plt.Axes):
            plot_single(axs, data, y_labels[0], phase, colors)
        else:
            for i, y_label in enumerate(y_labels):
                plot_single(axs[i], data, y_label, phase, colors)
                

plot_scoreboard('epoch', ['loss'], figsize=(6, 3))
plot_scoreboard('epoch', ['accuracy'], figsize=(6, 3))

# %%
plot_scoreboard('epoch', ['f1_score'], figsize=(6, 3))

# %%
for cc in class_names:
    plot_scoreboard('epoch', [f'f1_score {cc}'], figsize=(6, 3))

# %%
for cc in class_names:
    plot_scoreboard('epoch', [f'f1_score {cc}', f'precision {cc}', f'recall {cc}'], figsize=(6, 3))
